# %%
import pandas as pd
staty = pd.read_json("staty.json")
staty.set_index("name", inplace=True)
#staty[["population", "area"]]
staty["density"] = staty["population"] / staty["area"]
staty = staty.sort_values("density", ascending=False)
staty.head(20)
# Out:
#                            alpha2Code alpha3Code           capital    region  \
# name
# Macao                              MO        MAC                        Asia
# Monaco                             MC        MCO            Monaco    Europe
# Singapore                          SG        SGP         Singapore      Asia
# Hong Kong                          HK        HKG  City of Victoria      Asia
# Gibraltar                          GI        GIB         Gibraltar    Europe
# Bahrain                            BH        BHR            Manama      Asia
# Malta                              MT        MLT          Valletta    Europe
# Bermuda                            BM        BMU          Hamilton  Americas
# Maldives                           MV        MDV              Malé      Asia
# Sint Maarten (Dutch part)          SX        SXM       Philipsburg  Americas
# Bangladesh                         BD        BGD             Dhaka      Asia
# Holy See                           VA        VAT              Rome    Europe
# Jersey                             JE        JEY      Saint Helier    Europe
# Guernsey                           GG        GGY    St. Peter Port    Europe
# Saint Martin (French part)         MF        MAF           Marigot  Americas
# Barbados                           BB        BRB        Bridgetown  Americas
# Taiwan                             TW        TWN            Taipei      Asia
# Mauritius                          MU        MUS        Port Louis    Africa
# Aruba                              AW        ABW        Oranjestad  Americas
# Lebanon                            LB        LBN            Beirut      Asia
#
#                                      subregion  population       area  gini  \
# name
# Macao                             Eastern Asia      649100      30.00   NaN
# Monaco                          Western Europe       38400       2.02   NaN
# Singapore                   South-Eastern Asia     5535000     710.00  48.1
# Hong Kong                         Eastern Asia     7324300    1104.00  53.3
# Gibraltar                      Southern Europe       33140       6.00   NaN
# Bahrain                           Western Asia     1404900     765.00   NaN
# Malta                          Southern Europe      425384     316.00   NaN
# Bermuda                       Northern America       61954      54.00   NaN
# Maldives                         Southern Asia      344023     300.00  37.4
# Sint Maarten (Dutch part)            Caribbean       38247      34.00   NaN
# Bangladesh                       Southern Asia   161006790  147570.00  32.1
# Holy See                       Southern Europe         451       0.44   NaN
# Jersey                         Northern Europe      100800     116.00   NaN
# Guernsey                       Northern Europe       62999      78.00   NaN
# Saint Martin (French part)           Caribbean       36979      53.00   NaN
# Barbados                             Caribbean      285000     430.00   NaN
# Taiwan                            Eastern Asia    23503349   36193.00   NaN
# Mauritius                       Eastern Africa     1262879    2040.00   NaN
# Aruba                                Caribbean      107394     180.00   NaN
# Lebanon                           Western Asia     5988000   10452.00   NaN
#
#                                  density
# name
# Macao                       21636.666667
# Monaco                      19009.900990
# Singapore                    7795.774648
# Hong Kong                    6634.329710
# Gibraltar                    5523.333333
# Bahrain                      1836.470588
# Malta                        1346.151899
# Bermuda                      1147.296296
# Maldives                     1146.743333
# Sint Maarten (Dutch part)    1124.911765
# Bangladesh                   1091.053669
# Holy See                     1025.000000
# Jersey                        868.965517
# Guernsey                      807.679487
# Saint Martin (French part)    697.716981
# Barbados                      662.790698
# Taiwan                        649.389357
# Mauritius                     619.058333
# Aruba                         596.633333
# Lebanon                       572.904707
